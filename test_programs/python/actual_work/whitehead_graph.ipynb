# %%
from objects.FreeGroup import *

# %%
fg = getFreeGroup(4)
fg.get_hash_dict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 fg = getFreeGroup(4)
# ----> 2 fg.get_hash_dict()
#
# AttributeError: 'FreeGroup' object has no attribute 'get_hash_dict'
