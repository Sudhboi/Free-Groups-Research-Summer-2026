# %%
from objects import minimize, getFreeGroup, genRandWord, word
import time

# %%
fg = getFreeGroup(26)
w, l = genRandWord(fg, 200, 20)
print(w.get_copyable())
ctime = time.time()
mw = minimize(w, fg, show_trace=True)
print(mw)
print(time.time() - ctime)
# Out:
# d^-11 a^-14 e^-16 x^-7 a^19 t^14 m^6 o^-18 j^-14 v^19 l^-8 g^-8 t^-18 z^-20 l^-19
# 211 d⁻¹¹a⁻¹⁴e⁻¹⁶x⁻⁷a¹⁹t¹⁴m⁶o⁻¹⁸j⁻¹⁴v¹⁹l⁻⁸g⁻⁸t⁻¹⁸z⁻²⁰l⁻¹⁹
# {'e': aea⁻¹, 'x': axa⁻¹, 'a': a, 'b': b, 'c': c, 'd': d, 'f': f, 'g': g, 'h': h, 'i': i, 'j': j, 'k': k, 'l': l, 'm': m, 'n': n, 'o': o, 'p': p, 'q': q, 'r': r, 's': s, 't': t, 'u': u, 'v': v, 'w': w, 'y': y, 'z': z}
# 209 d⁻¹¹a⁻¹³e⁻¹⁶x⁻⁷a¹⁸t¹⁴m⁶o⁻¹⁸j⁻¹⁴v¹⁹l⁻⁸g⁻⁸t⁻¹⁸z⁻²⁰l⁻¹⁹
# {'e': aea⁻¹, 'x': axa⁻¹, 'a': a, 'b': b, 'c': c, 'd': d, 'f': f, 'g': g, 'h': h, 'i': i, 'j': j, 'k': k, 'l': l, 'm': m, 'n': n, 'o': o, 'p': p, 'q': q, 'r': r, 's': s, 't': t, 'u': u, 'v': v, 'w': w, 'y': y, 'z': z}
# 207 d⁻¹¹a⁻¹²e⁻¹⁶x⁻⁷a¹⁷t¹⁴m⁶o⁻¹⁸j⁻¹⁴v¹⁹l⁻⁸g⁻⁸t⁻¹⁸z⁻²⁰l⁻¹⁹
# {'e': aea⁻¹, 'x': axa⁻¹, 'a': a, 'b': b, 'c': c, 'd': d, 'f': f, 'g': g, 'h': h, 'i': i, 'j': j, 'k': k, 'l': l, 'm': m, 'n': n, 'o': o, 'p': p, 'q': q, 'r': r, 's': s, 't': t, 'u': u, 'v': v, 'w': w, 'y': y, 'z': z}
# 205 d⁻¹¹a⁻¹¹e⁻¹⁶x⁻⁷a¹⁶t¹⁴m⁶o⁻¹⁸j⁻¹⁴v¹⁹l⁻⁸g⁻⁸t⁻¹⁸z⁻²⁰l⁻¹⁹
# ...
