# %%
from objects import find_partitions, make_whitehead_graph, word, generate_wh_automorphism
# Out:
# /nix/store/gdyl89d3lgffvxb3qjqlh91m12x8lifr-python3-3.13.12-env/lib/python3.13/site-packages/graph_tool/draw/cairo_draw.py:1553: RuntimeWarning: Error importing Gtk module: ; GTK+ drawing will not work.
#   warnings.warn(msg, RuntimeWarning)

# %%
w = word("f^-5 b^-6 c^16 f^-13 c^-2 b^-14 f^18 b^-1 e^20 d^8 e^-6 f^19 a^17 b^17 e^15 c^8 b^13 f^-20 b^12 c^-6 d^-15 a^-12 b^16 d^15 f^-14 c^18 b^-4 c^-18 f^-1 c^-1 d^10 e^11 d^-4 a^-15 d^-3 e^-8 d^14 f^13 a^5 e^10 d^15 e^-18 d^-8 b^-11 a^-8 d^1 b^-13 a^9 e^-7 f^13 e^17 g^-19 f^1 a^-7 f^-5 g^19 f^3 c^8 d^5 e^9 a^17 e^2 f^18 e^-6 a^-17 e^15 c^-7 f^-8 g^-15 b^11 a^2 c^18 a^-9 d^11 f^10 c^-3 d^18 a^-4 d^-19 c^13 a^3 f^-18 d^-5 g^-20 f^3 d^-3 b^-10 e^19 a^-5 c^14 a^-6 e^-3 c^17 a^17")
g = make_whitehead_graph(w)
partlist = find_partitions(g)
print(partlist)
# Out:
# [({g⁻¹, f⁻¹, g}, {b⁻¹, d⁻¹, c, d, f, e⁻¹, e, a⁻¹, a, b, c⁻¹})]
