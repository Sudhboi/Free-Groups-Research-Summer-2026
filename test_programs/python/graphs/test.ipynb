# %%
from graph_tool.all import Graph, graph_draw
from objects.FreeGroup import *
# Out:
# /nix/store/p7cv1anip4s0zr7pv7jw2mhz398w7h2z-python3-3.13.12-env/lib/python3.13/site-packages/graph_tool/draw/cairo_draw.py:1553: RuntimeWarning: Error importing Gtk module: ; GTK+ drawing will not work.
#   warnings.warn(msg, RuntimeWarning)

# %%
f = getFreeGroup(26)

# %%
g = Graph()
g.add_edge_list([(i,) for i in f.alphabet], hashed=True, hash_type="object")
# Out:
# <VertexPropertyMap object with value type 'python::object', for Graph 0x7f709c674c20, at 0x7f6fcbb04a50>

# %%
graph_draw(g, vertex_text=g.vertex_index)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f709c674c20, at 0x7f6fcbab6000>

# %%
genRandWord(f, 2000, 4)
# Out:
# (e⁻³r³v⁴y⁻¹l⁻²v⁻²mq⁻³z³n³v⁻²t³h⁻⁴g⁻³l⁻³h²y⁻⁴g⁻⁴q³x³f⁴e⁴o⁻³k²r⁻²x⁻²f³rv²h⁻³us⁻³b³u⁻³b⁻⁴q⁴c²q²t⁻⁴m⁴r⁻³dr⁻¹j⁴h⁻³d⁻²o⁻³zvnh⁻³fh⁻¹q⁻³e³b⁻³x⁻⁴y²j⁻²xq⁻²r⁻²gu⁻⁴k³b³c⁻⁴d⁻³n²p⁻⁴h⁴y⁻³j²w⁻²x²e³c⁻³a⁻²j⁴q⁻³z⁴q²oj⁴x³s⁻⁴h⁻⁴z⁻²k⁻¹m⁻¹heu⁻¹a⁻²f³z²d⁻³m⁻²c⁻²i⁴z⁻³o⁻³h³c⁻²hr⁻³a⁻³sl⁻²n⁴vk²p⁻⁴v⁻³t⁻⁴g⁻⁴o⁻²z⁻³il⁴y⁻²d⁻⁴gwq⁻²j²m⁴k⁻⁴ow⁻²u³q⁻²v⁻¹x³mz⁻⁴k³g⁴l⁻¹w⁻³l⁻⁴v⁻²z⁻²s⁻⁴p⁻³o⁴z³r⁻³gz³t²b²j⁻³o²v⁴n⁻³j²i⁻⁴v⁴h⁻²b⁴pqg²l⁻³j⁻²x⁻⁴ik⁴v⁻⁴b⁻³a⁻¹n⁴al⁻³pb⁻⁴k⁻⁴c³qp⁻⁴x⁻³z⁻⁴y³j²c⁴i⁻³d³c⁻³x²cls⁴m⁻¹y⁻⁴g⁻³y⁴q²o⁴r²bp²r⁻²d³a⁻¹u²c⁻⁴s³qu⁻⁴q⁻⁴e⁻²g²a⁻²j⁻⁴i⁻²t⁻⁴f⁻²z⁴he⁻³s³f⁻³j⁻²r²a²u⁴l⁻²f⁻¹e⁻²i²g⁻⁴f²h⁻²m⁻⁴v⁴p⁻³u²p⁴m⁻²k⁻³q⁴g²h⁻³xhq⁻³r⁻²ozq⁻⁴i⁻³s³p³vci⁻²f⁻³q⁻³e³h⁻⁴q⁻⁴o²b⁻¹a⁻²q⁻⁴u⁻⁴o⁻¹c⁻³sk⁻³j³k⁴uv³m⁻¹r²w²r⁻¹x⁻⁴g⁻²e⁴p⁻¹jx⁻³d⁻¹o⁴u²e⁴a⁻³b⁻⁴q⁻¹b²l⁻¹i²n⁴d⁴y⁴o³a⁻⁴r⁻¹k²o⁻²xt³p⁴x⁻²e²s⁻³hf⁴xi⁴f⁻²h⁻³y⁻²jz⁻³of⁻²z²k⁻³x⁻¹b⁻³c⁻¹tg⁻¹n²x⁻⁴jl⁻³if²r⁻³o⁻¹s⁻⁴z⁻³j²o⁻²t⁻⁴l⁻¹r²y⁻¹t⁴c²u⁻⁴r⁻⁴v²e³hyb⁻³v⁻⁴l⁻⁴r²f⁻²z⁻²x⁻³q³y²q⁻³v⁻³hp⁻³rf⁴k⁻⁴d²l⁻³b⁻¹l⁴f⁴z²yt⁻⁴e⁻²v²e⁴rmf⁴xl²g³b⁴h³p⁴x⁻¹nq⁻²o⁻³d³a⁻⁴q⁻²k⁻³u²ch⁻⁴it⁴f²o⁻¹z⁻²n²w⁻²r²d³s⁻²v³u⁻³i²r⁻²c³w⁻⁴s⁻³n³u⁻⁴n⁻⁴s³vm²h⁻⁴c³n⁴q
# ...
