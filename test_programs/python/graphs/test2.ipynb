# %%
from objects.GraphFunctions import *
from objects.FreeGroup import *
# Out:
# /nix/store/p7cv1anip4s0zr7pv7jw2mhz398w7h2z-python3-3.13.12-env/lib/python3.13/site-packages/graph_tool/draw/cairo_draw.py:1553: RuntimeWarning: Error importing Gtk module: ; GTK+ drawing will not work.
#   warnings.warn(msg, RuntimeWarning)

# %%
fg = getFreeGroup(26)
w, l = genRandWord(fg, 200, 5)
print(w)
draw_whitehead_graph(fg, w)
# Out:
# b⁴r⁻⁵y⁻⁵e⁵z⁻⁵ez⁻²d⁵b⁻²c⁵p⁻⁴m⁵n⁻¹g²c⁵q⁴e⁻⁴h⁻⁵e⁻³d⁻⁵g⁻⁴m⁻¹t⁻⁵r⁴a⁻⁴b⁵j⁻²b²w⁻⁴u⁻³f⁻²q²x⁴o⁻²e²n⁻²z⁵g⁻¹ps⁻³r³j⁻⁵p²d⁵s⁵h³e⁻⁴o⁻³p⁻⁵u⁻¹f⁵x⁴v⁻⁵s⁻⁵r²f⁵h²y⁻³
